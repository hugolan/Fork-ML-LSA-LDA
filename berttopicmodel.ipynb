# %% [markdown]
# https://github.com/MaartenGr/BERTopic
#
# https://www.holisticseo.digital/python-seo/topic-modeling/

# %%
# %%capture
# !pip install bertopic

# %%
# !python -m spacy download fr_core_news_sm

# %%
import pandas as pd
import re
import numpy as np

# %%
from bertopic import BERTopic

# %%
import spacy
nlp = spacy.load("fr_core_news_sm")

# %%
df = pd.read_csv("impresso2.csv", sep=';')

# %%
# Remove null values
df = df[df['content'].notna()]

# Convert dates to datetime objects and sort by date
df.date = pd.to_datetime(df.date)
df = df.sort_values(by = "date")
df = df.reset_index(drop=True)

# %%
# Data was manually extracted with keywords so there is a lot of noise, these are phrases
# that appear in some of the bigger documents that are not relevant to our task -- might still need to add more
# Remove these articles from the dataframe

to_remove = ['CINÉMA Apollo 1 Faubourg', 'CINÉMA Eden Rue de la', 'NOUS RECHERCHONS', 'Ciné NEUCHÂTEL', \
             'Ciné LA CHAUX-DE-FONDS', 'AGENDA', 'APOLLO', 'ANIMATIONS', 'RATIONALISATION DES TRANSFERTS', \
             'REALITE', 'INTÉGRATION DU NÉGOCE DES OPTIONS', 'SOFFEX', 'www . hbo', 'Mythologies Primitive', \
             'GENEVE Marché', 'Morat-Central', 'GENEVE Reprise', 'monnaie plastique', 'La BCV', 'aint-Valentin', \
             'GENÈVE Marché', 'ÉCOLE DE NATATION', 'SOCIETES RÉSULTATS', 'SOCIETES SUISSE TRÉFILERIES', 'SOCIÉTÉS', \
             'Stock Exchange', 'CONGÉLATEUR BAHUT', 'USS Une', 'MARCHÉS BOURSIERS', 'TTVj', 'Bourse électronique', \
             'IAIIBERTé VIE']
df = df[~df.content.isin(to_remove)]
df = df[~(df.content.str.contains("bourse") & df.content.str.contains("banque"))]
df = df[df.content.str.count('026') < 3]
df = df[df.content.str.count('032') < 3]
df = df[df.content.str.count('00') < 6]

df = df.reset_index(drop=True)

# %%
# Remove articles that contain these regular expressions -- they are not relevant
test = df.content.apply(lambda x: re.search('\d\d\s\.\s\d\d', x))
test2 = df.content.apply(lambda x: re.search('\~\~', x))

tests = [test, test2]

for t in tests:
    none = []
    for i in range(len(t)):
        none.append(t[i] is None)
    none = pd.Series(none)

    none_index = np.where(~none)

    df = df.drop(none_index[0])
    df = df.reset_index(drop=True)

# %%
# Articles with multiple phone numbers are advertisements, remove them
test = df.content.apply(lambda x: len(re.findall('\d\d\d\s\d\d\s\d\d', x)))
df = df.drop(test[test > 2].index)
df = df.reset_index(drop=True)

# %%
# Remove really short articles
df = df[df.content.str.len() > 300]
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (4762, 21)

# %%
from preprocessing import *
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
data = spacy_prep(df.content)

# %%
#df_no_keywords = df.content.apply(lambda x: remove_keywords(x))
#data_nk = spacy_prep(df_no_keywords)

# %%
# Transform list of words back into strings
data_ready = []
for doc in data:
  data_ready.append(' '.join(doc))

# %%
# Fit a topic model
#can add different sentence transformers
topic_model = BERTopic(language="french")
topics, probs = topic_model.fit_transform(data_ready)
# Out:
# Downloading:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
# Look at topics (-1 are outliers)
topic_model.get_topic_info()
# Out:
#     Topic  Count                                 Name
# 0      -1   2032        -1_jeu_video_nintendo_console
# 1       0    228       0_course_voiture_rally_circuit
# 2       1    106       1_banque_bourse_suisse_societe
# 3       2    105             2_enfant_jean_noel_petit
# 4       3     93              3_blanc_pierre_noir_jeu
# ..    ...    ...                                  ...
# 78     77     10  77_ballon_deruns_ballon_rouge_rouge
# 79     78     10             78_toy_eye_jouet_eye_toy
# 80     79     10           79_abe_rome_agrippa_shadow
# 81     80     10      80_joystick_lcr_killzone_minish
# 82     81     10     81_duel_duel_master_carte_master
#
# [83 rows x 3 columns]

# %%
# Look at first topic
topic_model.get_topic(0)
# Out:
# [('course', 0.02213726674883922),
#  ('voiture', 0.015677314277290362),
#  ('rally', 0.015305212237113733),
#  ('circuit', 0.015264973055434599),
#  ('simulation', 0.015257614918504568),
#  ('gran', 0.012882467861239321),
#  ('turismo', 0.012349099836610108),
#  ('bolide', 0.012268554158325671),
#  ('jeu', 0.012030521742773036),
#  ('mode', 0.011097255937952378)]

# %%
# Visualize topics
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="d1b7ee91-d7be-4ced-ad6d-7721dae6479f" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1b7ee91-d7be-4ced-ad6d-7721dae6479f")) {                    Plotly.newPlot(                        "d1b7ee91-d7be-4ced-ad6d-7721dae6479f",                        [{"customdata":[[0,"course | voiture | rally | circuit | simulation",228],[1,"banque | bourse | suisse | societe | million",106],[2,"enfant | jean | noel | petit | parent",105],[3,"blanc | pierre | noir | jeu | decan",93],[4,"fossett | match | sport | football | steve",92],[5,"xbox | microsoft | live | xbo | console",76],[6,"atari | st | ordinateur | prix | moniteur",69],[7,"telephone | mobile | appareil | nokia | ecran",61],[8,"envoyer | mazel | courrier | concours_gagner | sms",59],[9,"fiche_technique | fiche | xbox | technique | gameplay",54],[10,"film | cinema | acteur | rocky | image",53],[11,"concert | samedi | musique | soiree | rock",52],[12,"burnout | pokemon | rainbow | lego | veger",50],[13,"project | zero | project_zero | zombie | vampire",48],[14,"pressez | start | octopus | super | neuchatel",48],[15,"hockey | nhl | thibaut | ligue | lna",45],[16,"cell | sam | splinter | fisher | solid",44],[17,"professeur | layton | professeur_layton | monster | enigme",42],[18,"apple | ordinateur | silicon | dollar | informatique",41],[19,"tennis | nadal | golf | rafael | virtua",41],[20,"console | pocket | game | gameboy | boy",39],[21,"dimanche | gagner | concourir_gagner | reponder_dimanche | minuit_question",38],[22,"dreamcast | sega | console | jeu | sonic",38],[23,"teste | support | wii | ps | support_teste",38],[24,"gagnant | tirage | lecteur | gagner | neuchatel",35],[25,"chartsz | fifa | ch | siea | entertainment",34],[26,"gta | tang | kri | mark | theft",31],[27,"god | war | killzone | kratos | call",31],[28,"multimedia | silicon | technologie | suisse | informatique",30],[29,"soccer | fifa | football | simulation | power",30],[30,"postal | lynx | game | rubrique | neuchatel",29],[31,"kong | donkey | donkey_kong | banjo | crossing",28],[32,"snowboard | ski | snowboarding | amped | winter",28],[33,"polylan | suisse | stand | bubsy | grotte",28],[34,"ordinateur | logiciel | atari | informatique | micro",28],[35,"zelda | link | the | legend | of",27],[36,"jak | heart | jeu | yoshi | stitch",27],[37,"jet | pitt | film | croft | jolie",27],[38,"rom | philippe | racine | braille | fribourg",26],[39,"fiche | fiche_technique | wii | technique | band_sonore",25],[40,"violence | violent | jeune | pet
topic 1</b><br>Words: zeppelin, led, led_zeppelin, atlantic, afp","<b>Topic 1</b><br>Words: douane, lapin_cretin, cretin, lapin, potentiellement"],"marker":{"color":"#E69F00"},"mode":"lines","name":"1_banque_bourse_suisse_societe","x":[1979.963,1981.85,1983.7,1985.55,1987.4,1989.25,1991.1,1992.95,1994.8,1996.65,1998.5,2000.35,2002.2,2004.05,2005.9,2011.45],"y":[2,4,7,5,6,13,2,18,22,14,3,4,1,2,2,1],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: lear, ieisk, gelure, blanc, khan","<b>Topic 2</b><br>Words: ollon, panoramic, hotel, fankhauser, payot","<b>Topic 2</b><br>Words: boujenah, salade, michel, saumon, legumes","<b>Topic 2</b><br>Words: caan, midler, bette, dixie, bub","<b>Topic 2</b><br>Words: ludotheque, desert, contes, pulp, enfant","<b>Topic 2</b><br>Words: noel, animal_compagnie, animal, abel, prix","<b>Topic 2</b><br>Words: titeuf, noel, pere, sankei, enfant","<b>Topic 2</b><br>Words: enfant, ludo, gerald, becker, paz","<b>Topic 2</b><br>Words: troillet, jean, jean_troillet, erhard, leverest","<b>Topic 2</b><br>Words: lara, croft, angelina, verhoven, bont","<b>Topic 2</b><br>Words: uderzo, goscinny, lowenstein, william, cerveau","<b>Topic 2</b><br>Words: jules, jobs, impot, steve, aberghouss","<b>Topic 2</b><br>Words: donjon, claude, robert, jean, lucien","<b>Topic 2</b><br>Words: audeguy, renier, yves, fabre, stephane","<b>Topic 2</b><br>Words: enfant, pourchet, jean, parent, maria","<b>Topic 2</b><br>Words: josi, corse, perret, roman_josi, gentil","<b>Topic 2</b><br>Words: maladiere, auditeur, kids, centre, compagnie"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"2_enfant_jean_noel_petit","x":[1979.963,1985.55,1989.25,1991.1,1992.95,1994.8,1996.65,1998.5,2000.35,2002.2,2004.05,2005.9,2007.75,2009.6,2011.45,2013.3,2015.15],"y":[1,2,4,4,10,9,13,5,3,2,4,6,15,6,11,9,1],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: pierre, blanc, noir, pierre_noir, cassette","<b>Topic 3</b><br>Words: blanc, noir, pierre, territoire, ban","<b>Topic 3</b><br>Words: brooks, richard, fleischer, film, jeanrichard","<b>Topic 3</b><br>Words: piece, jeanneret, appartement, appartement_piece, avocat","<b>Topic 3</b><br>Words: weber, cari, franz, jouet, noel","<b>Topic 3</b><br>Words: decan, boy, game, game_boy, super","<b>Topic 3</b><br>Words: cuttat, michel, michel_cuttat, pog, chimiste","<b>Topic 3</b><br>Words: mcqueen, algerie, ros ...

# %%
# Look at topics by newspaper
topics_per_class = topic_model.topics_per_class(data_ready, topics, newspapers)

# %%
topic_model.visualize_topics_per_class(topics_per_class)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="6fb5f080-5104-4e94-92a9-550160f7c588" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fb5f080-5104-4e94-92a9-550160f7c588")) {                    Plotly.newPlot(                        "6fb5f080-5104-4e94-92a9-550160f7c588",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: course, rally, voiture, simulation, circuit","<b>Topic 0</b><br>Words: cinema, electronique, prix, simulation, simpson","<b>Topic 0</b><br>Words: course, voiture, rally, circuit, simulation","<b>Topic 0</b><br>Words: electronique, cinema, consommateur, marche, paramout","<b>Topic 0</b><br>Words: course, voiture, circuit, gran, turismo"],"marker":{"color":"#E69F00"},"name":"0_course_voiture_rally_circuit","orientation":"h","visible":true,"x":[113,2,102,1,10],"y":["EXP","GDL","IMP","JDG","LLE"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: banque, patent, echange, suisse, national","<b>Topic 1</b><br>Words: bourse, banque, suisse, societe, million","<b>Topic 1</b><br>Words: bourse, banque, suisse, million, secom","<b>Topic 1</b><br>Words: tache, emploi, main_\u0153uvre, pays, suisse","<b>Topic 1</b><br>Words: bourse, banque, suisse, societe, million","<b>Topic 1</b><br>Words: suisse, banque, patent, dechange, bourse","<b>Topic 1</b><br>Words: olten, usego, collaborateur, eng, seewen"],"marker":{"color":"#56B4E9"},"name":"1_banque_bourse_suisse_societe","orientation":"h","visible":"legendonly","x":[13,25,11,1,39,16,1],"y":["EXP","GDL","IMP","LLS","JDG","LLE","SDT"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: enfant, jean, titeuf, petit, noel","<b>Topic 2</b><br>Words: abel, sauthier, vetroz, pays, illuminee","<b>Topic 2</b><br>Words: ollon, panoramic, noel, sankei, hotel","<b>Topic 2</b><br>Words: enfant, titeuf, jean, petit, uderzo","<b>Topic 2</b><br>Words: noel, pere, pere_noel, che, cct","<b>Topic 2</b><br>Words: noel, sankei, caan, midler, bette","<b>Topic 2</b><br>Words: jean, enfant, troillet, boujenah, parent"],"marker":{"color":"#009E73"},"name":"2_enfant_jean_noel_petit","orientation":"h","visible":"legendonly","x":[36,1,4,33,2,5,24],"y":["EXP","LCE","GDL","IMP","LLS","JDG","LLE"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: decan, jeremy, blanc, pierre, boy","<b>Topic 3</b><br>Words: bastien, patrick, papa, bricoleur, maman","<b>Topic 3</b><br>Words: chessex, haydn, mozart, tranquillisant, jacques","<b>Topic 3</b><br>Words: blanc, pierre, noir, pierre_noir, territoire","<b>Topic 3</b><br>Words: sexo, fortun, leadership, ette, communications","<b>Topic 3</b><br>Words: cassette, pierre, blanc, jeune, noir"],"marker":{"color":"#F0E442"},"name":"3_blanc_pierre_noir_jeu","orientation":"h","visible":"legendonly","x":[36,1,2,30,1,23],"y":["EXP","LCE","GDL","IMP","JDG","LLE"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 4</b><br>Words: fossett, match, steve, football, suisse","<b>Topic 4</b><br>Words: bps, maret, martigny, meunier, formaz","<b>Topic 4</b><br>Words: loret, sport, alain, football, foot_salle","<b>Topic 4</b><br>Words: football, fossett, sport, match, steve","<b>Topic 4</b><br>Words: loret, sport, alain, alain_loret, sportif","<b>Topic 4</b><br>Words: fossett, club, med, match, steve"],"marker":{"color":"#D55E00"},"name":"4_fossett_match_sport_football","orientation":"h","visible":"legendonly","x":[24,1,2,26,1,38],"y":["EXP","LCE","GDL","IMP","JDG","LLE"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 5</b><br>Words: xbox, microsoft, live, xbo, console","<b>Topic 5</b><br>Words: ultra, baptisee, retardee, avril, fabricant_mondial","<b>Topic 5</b><br>Words: xbox, microsoft, live, console, xbo","<b>Topic 5</b><br>W ...

# %%
#topic_model.get_representative_docs()

# %% [markdown]
# ### Reduce the number of topics

# %%
# Reduce the number of topics
new_topics, new_probs = topic_model.reduce_topics(data_ready, topics, probs, nr_topics=30)

# %%
topics_over_time = topic_model.topics_over_time(data_ready, new_topics, years, nr_bins=20)
topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=8)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="17dd3301-6a3c-4d9e-95f7-1168c5e8af85" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 6</b><br>Words: pierre, blanc, noir, pierre_noir, cassette","<b>Topic 6</b><br>Words: blanc, noir, pierre, territoire, point","<b>Topic 6</b><br>Words: brooks, film, richard, club, fleischer","<b>Topic 6</b><br>Words: piece, jeanneret, appartement, appartement_piece, avocat","<b>Topic 6</b><br>Words:  ...

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                         Name
# 0      -1   2691                -1_jeu_video_nintendo_console
# 1       0    243              0_course_jeu_voiture_simulation
# 2       1    139               1_suisse_bourse_banque_million
# 3       2    136                       2_support_teste_ps_wii
# 4       3    105                     3_enfant_jean_noel_petit
# 5       4     98               4_neuchatel_super_postal_start
# 6       5     97             5_atari_ordinateur_logiciel_prix
# 7       6     93                      6_pierre_blanc_noir_jeu
# 8       7     92               7_fossett_sport_match_football
# 9       8     76                8_xbox_microsoft_console_live
# 10      9     61            9_telephone_mobile_appareil_ecran
# 11     10     59                10_envoyer_mazel_courrier_sms
# 12     11     58  11_dimanche_gagner_semaine_concourir_gagner
# 13     12     55                 12_game_boy_console_game_boy
# 14     13     55             13_gagnant_tirage_lecteur_gagner
# 15     14     54      14_fiche_fiche_technique_xbox_technique
# 16     15     53                  15_film_cinema_acteur_rocky
# 17     16     52               16_samedi_concert_musique_soir
# 18     17     50               17_burnout_jeu_pokemon_rainbow
# 19     18     48             18_zero_project_project_zero_jeu
# 20     19     46                      19_chartsz_fifa_ch_siea
# 21     20     45                   20_hockey_nhl_equipe_ligue
# 22     21     44                  21_cell_sam_splinter_fisher
# 23     22     43  22_fiche_fiche_technique_technique_gameplay
# 24     23     42        23_professeur_aventure_layton_monster
# 25     24     41                  24_tennis_nadal_golf_rafael
# 26     25     41           25_apple_ordinateur_dollar_silicon
# 27     26     40          26_snowboard_ski_snowboarding_amped
# 28     27     38                27_dreamcast_sega_jeu_console
# 29     28     36          28_mario_super_super_mario_nintendo
# 30     29     31                         29_gta_tang_mark_kri

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="f739695c-b163-44fb-a81f-bf9f49e58a3b" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f739695c-b163-44fb-a81f-bf9f49e58a3b")) {                    Plotly.newPlot(                        "f739695c-b163-44fb-a81f-bf9f49e58a3b",                        [{"customdata":[[0,"course | jeu | voiture | simulation | circuit",243],[1,"suisse | bourse | banque | million | societe",139],[2,"support | teste | ps | wii | pc",136],[3,"enfant | jean | noel | petit | faire",105],[4,"neuchatel | super | postal | start | adresse",98],[5,"atari | ordinateur | logiciel | prix | ibm",97],[6,"pierre | blanc | noir | jeu | video",93],[7,"fossett | sport | match | football | steve",92],[8,"xbox | microsoft | console | live | xbo",76],[9,"telephone | mobile | appareil | ecran | nokia",61],[10,"envoyer | mazel | courrier | sms | concours_gagner",59],[11,"dimanche | gagner | semaine | concourir_gagner | reponder_dimanche",58],[12,"game | boy | console | game_boy | gameboy",55],[13,"gagnant | tirage | lecteur | gagner | neuchatel",55],[14,"fiche | fiche_technique | xbox | technique | graphisme",54],[15,"film | cinema | acteur | rocky | image",53],[16,"samedi | concert | musique | soir | soiree",52],[17,"burnout | jeu | pokemon | rainbow | lego",50],[18,"zero | project | project_zero | jeu | film",48],[19,"chartsz | fifa | ch
JDG","LLE"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: banque, milliard, suisse, million, patent","<b>Topic 1</b><br>Words: suisse, bourse, banque, societe, million","<b>Topic 1</b><br>Words: bourse, suisse, banque, milliard, million","<b>Topic 1</b><br>Words: emploi, tache, pays, main_\u0153uvre, suisse","<b>Topic 1</b><br>Words: bourse, suisse, million, banque, societe","<b>Topic 1</b><br>Words: suisse, bourse, banque, patent, national","<b>Topic 1</b><br>Words: olten, usego, collaborateur, eng, travailleur"],"marker":{"color":"#56B4E9"},"name":"1_suisse_bourse_banque_million","orientation":"h","visible":"legendonly","x":[20,33,13,1,49,22,1],"y":["EXP","GDL","IMP","LLS","JDG","LLE","SDT"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: support, teste, ps, wii, pc","<b>Topic 2</b><br>Words: support, teste, ps, wii, pc"],"marker":{"color":"#009E73"},"name":"2_support_teste_ps_wii","orientation":"h","visible":"legendonly","x":[69,67],"y":["EXP","IMP"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: enfant, petit, jean, noel, titeuf","<b>Topic 3</b><br>Words: abel, sauthier, vetroz, pays, merveilleux","<b>Topic 3</b><br>Words: ollon, noel, panoramic, hotel, sankei","<b>Topic 3</b><br>Words: enfant, petit, jean, titeuf, noel","<b>Topic 3</b><br>Words: noel, pere, pere_noel, che, cct","<b>Topic 3</b><br>Words: noel, sankei, midler, bette, caan","<b>Topic 3</b><br>Words: jean, enfant, troillet, petit, parent"],"marker":{"color":"#F0E442"},"name":"3_enfant_jean_noel_petit","orientation":"h","visible":"legendonly","x":[36,1,4,33,2,5,24],"y":["EXP","LCE","GDL","IMP","LLS","JDG","LLE"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 4</b><br>Words: neuchatel, super, postal, start, adresse","<b>Topic 4</b><br>Words: marjane, satrapi, teheran, persepoli, matins"],"marker":{"color":"#D55E00"},"name":"4_neuchatel_super_postal_start","orientation":"h","visible":"legendonly","x":[96,2],"y":["EXP","IMP"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 5</b><br>Words: atari, ordinateur, informatique, logiciel, cherche","<b>Topic 5</b><br>Words: atari, ordinateur, logiciel, bull, appareil","<b>Topic 5</b><br>Words: atari, ordinateur, disquette, logiciel, informatique","<b>Topic 5</b><br>Words: atari, ordinateur, logiciel, bull, appareil","<b>Topic 5</b><br>Words: atari, prix, ordinateur, st, moniteur"],"marker":{"color":"#0072B2"},"name":"5_atari_ordinateur_logiciel_prix","orientation":"h","visible":"legendonly","x":[10,9,25,9,44],"y":["EXP","GDL","IMP","JDG","LLE"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 6</b><br>Words: decan, jeu, video, boy, pierre","<b>Topic 6</b><br>Words: bastien, patrick, papa, maman, bricoleur","<b>Topic 6</b><br>Words: chessex, haydn, mozart, tranquillisant, jacques","<b>Topic 6</b><br>Words: blanc, pierre, noir, jeu, territoire","<b>Topic 6</b><br ...

# %%
# Can change labels here before plotting
topics_over_time
# Out:
#      Topic  ...                                   Name
# 0       -1  ...          -1_jeu_video_nintendo_console
# 1        1  ...         1_suisse_bourse_banque_million
# 2        3  ...               3_enfant_jean_noel_petit
# 3        6  ...                6_pierre_blanc_noir_jeu
# 4       17  ...         17_burnout_jeu_pokemon_rainbow
# ..     ...  ...                                    ...
# 328     18  ...       18_zero_project_project_zero_jeu
# 329     20  ...             20_hockey_nhl_equipe_ligue
# 330     21  ...            21_cell_sam_splinter_fisher
# 331     23  ...  23_professeur_aventure_layton_monster
# 332     26  ...    26_snowboard_ski_snowboarding_amped
#
# [333 rows x 5 columns]
